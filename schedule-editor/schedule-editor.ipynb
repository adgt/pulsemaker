# %%
# %config InlineBackend.figure_format = 'svg'
from pulseviz import ScheduleEditor

# %%
sch = ScheduleEditor()
sch

# %%
sch._phases
# Out:
# {'d0': [[0, 0]]}

# %%
aaa = {'d0': [[0, 0]]}
phase_array = aaa['d0']
phase_array
# Out:
# [[0, 0]]

# %%
phase_array[-1][0]
# Out:
# 0
